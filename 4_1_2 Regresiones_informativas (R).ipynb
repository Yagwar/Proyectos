# %%
library(psych)

# %%
datos=read.csv("datos_out_punts.csv", encoding="UTF-8", row.names=1, stringsAsFactors=T)
datos_norm=read.csv("features_normalized.csv", encoding="UTF-8", row.names=1, stringsAsFactors=F)
pruebas=read.csv("pruebas_variables.csv", encoding="UTF-8", stringsAsFactors=F, row.names=1)

# %%
datos$ebc_neducativo=factor(datos$ebc_neducativo, ordered = TRUE, levels = c("primaria", "secundaria", "universidad", "postgrado"))

# %%
variables_y=c("ebc_humor", "ebc_relax","ebc_energia", "ebc_levantado","ebc_interesantes",
              "ebc_nervioso","ebc_preocupacion","ebc_tranquilo", "ebc_desagradable", "ebc_inquieto", "ebc_temor",
               "escala_bienestar","escala_HADS","discret_bienestar","discret_HADS",'centil_bienestar',
               'z_bienestar', 'centil_HADS', 'z_HADS','flag_bienestar_z','flag_HADS_z', 'flag_warning_z')

# %%
# features_x=datos[,!(colnames(datos)%in%variables_y)]
# features_y=datos[,(colnames(datos)%in%variables_y)]
# colnames(features_x)
# colnames(features_y)

# %%
corr_inf_dist=read.csv("variables_correlaciones_informativas.csv", stringsAsFactors=F, row.names=1, encoding="UTF-8")
# str(corr_inf_dist)
# rownames(corr_inf_dist)

# %% [markdown]
# # Regresión Logística
# * [ejemplo 1 (r-statistics.co)](http://r-statistics.co/Logistic-Regression-With-R.html)
# * [ejemplo 2 (r-bloggers)](https://www.r-bloggers.com/how-to-perform-a-logistic-regression-in-r/)
# * [ejemplo 3 (UCLA)](https://stats.idre.ucla.edu/r/dae/logit-regression/)

# %%
# pred_name="discret_bienestar"
# pred_name="discret_HADS"
# pred_name="flag_discret"

# n_preds=10
# preds_columns=row.names(corr_inf_dist)[order(corr_inf_dist[paste(pred_name,"_dist",sep="")],decreasing=TRUE)[1:n_preds]] # top distancias
# preds_columns=row.names(corr_inf_dist)[order(corr_inf_dist[paste(pred_name,"_importance_mean",sep="")],decreasing=TRUE)[1:n_preds]] # top importancia
# preds_columns=row.names(corr_inf_dist)[order(corr_inf_dist[pred_name],decreasing=TRUE)[1:n_preds]] # Top correlación

# print(preds_columns)
# preds_columns=c(preds_columns,pred_name)
# preds_columns=gsub(" ", ".",preds_columns) # Reemplazar los espacios con puntos (R no es capaz de procesar nombres de variables copn espacios... ... ...)
# predictions_df=datos_norm[,colnames(datos_norm)%in%preds_columns]

# model <- glm(discret_bienestar ~.,family=binomial(link='logit'),data=predictions_df)
# model <- glm(discret_HADS ~.,family=binomial(link='logit'),data=predictions_df)
# model <- glm(flag_discret ~.,family=binomial(link='logit'),data=predictions_df)

# %%
pred_name="discret_bienestar"

n_preds=10
preds_columns=row.names(corr_inf_dist)[order(corr_inf_dist[paste(pred_name,"_dist",sep="")],decreasing=TRUE)[1:n_preds]] # top distancias

preds_columns=c(preds_columns,pred_name)
preds_columns=gsub(" ", ".",preds_columns)
print(preds_columns)

predictions_df=datos_norm[,colnames(datos_norm)%in%preds_columns]

model <- glm(discret_bienestar ~.,family=binomial(link='logit'),data=predictions_df)

summary(model)
summary(model)$coefficients
exp(coef(model))
# Out:
#  [1] "ebc_animo"                           "ebc_susalud"
#  [3] "ebc_r_viven"                         "ebc_pal_futuro_6_Es.desesperanzador"
#  [5] "ebc_sufamilia"                       "ebc_pal_futuro_2_Positivo"
#  [7] "ebc_sueducacion"                     "ebc_susfinanzas"
#  [9] "ebc_actrecreacion_Si"                "ebc_r_noviven"
# [11] "discret_bienestar"
# Call:
# glm(formula = discret_bienestar ~ ., family = binomial(link = "logit"),
#     data = predictions_df)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.8804  -0.6445   0.3375   0.6670   2.2756
#
# Coefficients:
#                                     Estimate Std. Error z value Pr(>|z|)
# (Intercept)                           5.4187     0.3182  17.030  < 2e-16 ***
# ebc_actrecreacion_Si                 -0.5282     0.1291  -4.091 4.30e-05 ***
# ebc_pal_futuro_2_Positivo            -0.5470     0.1657  -3.302 0.000959 ***
# ebc_pal_futuro_6_Es.desesperanzador   0.7525     0.1862   4.042 5.30e-05 ***
# ebc_animo                            -2.7020     0.2718  -9.942  < 2e-16 ***
# ebc_r_viven                          -1.1866     0.2650  -4.478 7.54e-06 ***
# ebc_r_noviven                        -0.4750     0.2494  -1.905 0.056831 .
# ebc_susfinanzas                      -0.6095     0.2060  -2.959 0.003088 **
# ebc_sueducacion                      -0.8231     0.2387  -3.447 0.000566 ***
# ebc_susalud                          -1.7775     0.2692  -6.603 4.02e-11 ***
# ebc_sufamilia                        -0.3104     0.2672  -1.162 0.245359
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 2086.9  on 1758  degrees of freedom
# Residual deviance: 1512.6  on 1748  degrees of freedom
# AIC: 1534.6
#
# Number of Fisher Scoring iterations: 5
#                                     Estimate   Std. Error z value
# (Intercept)                          5.4187375 0.3181842  17.030192
# ebc_actrecreacion_Si                -0.5282251 0.1291199  -4.090965
# ebc_pal_futuro_2_Positivo           -0.5470339 0.1656520  -3.302307
# ebc_pal_futuro_6_Es.desesperanzador  0.7524766 0.1861619   4.042054
# ebc_animo                           -2.7020105 0.2717682  -9.942336
# ebc_r_viven                         -1.1865712 0.2649839  -4.477899
# ebc_r_noviven                       -0.4749913 0.2493910  -1.904605
# ebc_susfinanzas                     -0.6095371 0.2060029  -2.958876
# ebc_sueducacion                     -0.8230596 0.2387415  -3.447492
# ebc_susalud                         -1.7775309 0.2691882  -6.603302
# ebc_sufamilia                       -0.3104334 0.2672246  -1.161695
#                                     Pr(>|z|)
# (Intercept)                         4.904310e-65
# ebc_actrecreacion_Si                4.295813e-05
# ebc_pal_futuro_2_Positivo           9.589303e-04
# ebc_pal_futuro_6_Es.desesperanzador 5.298501e-05
# ebc_animo                           2.723631e-23
# ebc_r_viven                         7.538139e-06
# ebc_r_noviven                       5.683143e-02
# ebc_susfinanzas                     3.087635e-03
# ebc_sueducacion                     5.658169e-04
# ebc_susalud                         4.020991e-11
# ebc_sufamilia                       2.453595e-01
#                         (Intercept)                ebc_actrecreacion_Si
#                        225.59412854                          0.58965064
#           ebc_pal_futuro_2_Positivo ebc_pal_futuro_6_Es.desesperanzador
#                          0.57866362                          2.12224952
#                           ebc_animo                         ebc_r_viven
#                          0.06707053                          0.30526618
#                       ebc_r_noviven                     ebc_susfinanzas
#                          0.62189044                          0.54360245
#                     ebc_sueducacion                         ebc_susalud
#                          0.43908618                          0.16905504
#                       ebc_sufamilia
#                          0.73312918

# %%
pred_name="discret_HADS"

n_preds=10
preds_columns=row.names(corr_inf_dist)[order(corr_inf_dist[paste(pred_name,"_dist",sep="")],decreasing=TRUE)[1:n_preds]] # top distancias

preds_columns=c(preds_columns,pred_name)
preds_columns=gsub(" ", ".",preds_columns)
print(preds_columns)

predictions_df=datos_norm[,colnames(datos_norm)%in%preds_columns]
model <- glm(discret_HADS ~.,family=binomial(link='logit'),data=predictions_df)

summary(model)
summary(model)$coefficients
exp(coef(model))
# Out:
#  [1] "ebc_animo"                           "ebc_pal_futuro_6_Es.desesperanzador"
#  [3] "ebc_susalud"                         "ebc_agresivo"
#  [5] "ebc_susfinanzas"                     "ebc_pal_futuro_2_Positivo"
#  [7] "ebc_r_viven"                         "ebc_pal_futuro_1_Será.amenazante"
#  [9] "ebc_deudas_Pagar.deudas"             "ebc_pal_futuro_7_Es.muy.negativo"
# [11] "discret_HADS"
# Call:
# glm(formula = discret_HADS ~ ., family = binomial(link = "logit"),
#     data = predictions_df)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.5491  -0.9676   0.4284   0.8458   2.2223
#
# Coefficients:
#                                     Estimate Std. Error z value Pr(>|z|)
# (Intercept)                           2.7060     0.2488  10.878  < 2e-16 ***
# ebc_pal_futuro_1_Será.amenazante      0.3081     0.1412   2.182 0.029133 *
# ebc_pal_futuro_2_Positivo            -0.5123     0.1529  -3.351 0.000805 ***
# ebc_pal_futuro_6_Es.desesperanzador   0.7967     0.1628   4.892 9.97e-07 ***
# ebc_pal_futuro_7_Es.muy.negativo      0.4894     0.2688   1.821 0.068624 .
# ebc_deudas_Pagar.deudas               0.3999     0.1282   3.120 0.001810 **
# ebc_animo                            -2.3317     0.2375  -9.820  < 2e-16 ***
# ebc_agresivo                         -1.0741     0.2130  -5.042 4.60e-07 ***
# ebc_r_viven                          -0.2447     0.2224  -1.100 0.271210
# ebc_susfinanzas                      -0.4069     0.2008  -2.026 0.042725 *
# ebc_susalud                          -0.8047     0.2230  -3.608 0.000309 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 2309.7  on 1758  degrees of freedom
# Residual deviance: 1840.0  on 1748  degrees of freedom
# AIC: 1862
#
# Number of Fisher Scoring iterations: 5
#                                     Estimate   Std. Error z value
# (Intercept)                          2.7060314 0.2487607  10.878052
# ebc_pal_futuro_1_Será.amenazante     0.3080841 0.1412142   2.181679
# ebc_pal_futuro_2_Positivo           -0.5122959 0.1528773  -3.351027
# ebc_pal_futuro_6_Es.desesperanzador  0.7966795 0.1628470   4.892195
# ebc_pal_futuro_7_Es.muy.negativo     0.4893865 0.2687632   1.820884
# ebc_deudas_Pagar.deudas              0.3999026 0.1281806   3.119837
# ebc_animo                           -2.3317079 0.2374555  -9.819558
# ebc_agresivo                        -1.0740751 0.2130218  -5.042089
# ebc_r_viven                         -0.2447386 0.2224331  -1.100280
# ebc_susfinanzas                     -0.4068722 0.2007870  -2.026388
# ebc_susalud                         -0.8046894 0.2230434  -3.607769
#                                     Pr(>|z|)
# (Intercept)                         1.466643e-27
# ebc_pal_futuro_1_Será.amenazante    2.913324e-02
# ebc_pal_futuro_2_Positivo           8.051248e-04
# ebc_pal_futuro_6_Es.desesperanzador 9.971760e-07
# ebc_pal_futuro_7_Es.muy.negativo    6.862449e-02
# ebc_deudas_Pagar.deudas             1.809511e-03
# ebc_animo                           9.274944e-23
# ebc_agresivo                        4.604762e-07
# ebc_r_viven                         2.712103e-01
# ebc_susfinanzas                     4.272509e-02
# ebc_susalud                         3.088407e-04
#                         (Intercept)    ebc_pal_futuro_1_Será.amenazante
#                         14.96974881                          1.36081539
#           ebc_pal_futuro_2_Positivo ebc_pal_futuro_6_Es.desesperanzador
#                          0.59911848                          2.21816326
#    ebc_pal_futuro_7_Es.muy.negativo             ebc_deudas_Pagar.deudas
#                          1.63131516                          1.49167934
#                           ebc_animo                        ebc_agresivo
#                          0.09712972                          0.34161358
#                         ebc_r_viven                     ebc_susfinanzas
#                          0.78290919                          0.66572928
#                         ebc_susalud
#                          0.44722683

# %%
pred_name="flag_discret"

n_preds=10
preds_columns=row.names(corr_inf_dist)[order(corr_inf_dist[paste(pred_name,"_dist",sep="")],decreasing=TRUE)[1:n_preds]] # top distancias

preds_columns=c(preds_columns,pred_name)
preds_columns=gsub(" ", ".",preds_columns)
print(preds_columns)

predictions_df=datos_norm[,colnames(datos_norm)%in%preds_columns]
model <- glm(flag_discret ~.,family=binomial(link='logit'),data=predictions_df)

summary(model)
summary(model)$coefficients
exp(coef(model))
# Out:
#  [1] "ebc_animo"                           "ebc_susalud"
#  [3] "ebc_pal_futuro_6_Es.desesperanzador" "ebc_r_viven"
#  [5] "ebc_susfinanzas"                     "ebc_agresivo"
#  [7] "ebc_pal_futuro_2_Positivo"           "ebc_pal_futuro_1_Será.amenazante"
#  [9] "ebc_sueducacion"                     "ebc_supais"
# [11] "flag_discret"
# Call:
# glm(formula = flag_discret ~ ., family = binomial(link = "logit"),
#     data = predictions_df)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.6156  -0.8187   0.2873   0.8057   2.5268
#
# Coefficients:
#                                     Estimate Std. Error z value Pr(>|z|)
# (Intercept)                           3.4771     0.2510  13.852  < 2e-16 ***
# ebc_pal_futuro_1_Será.amenazante      0.2746     0.1400   1.961 0.049855 *
# ebc_pal_futuro_2_Positivo            -0.6204     0.1677  -3.699 0.000217 ***
# ebc_pal_futuro_6_Es.desesperanzador   0.9945     0.1564   6.359 2.04e-10 ***
# ebc_animo                            -2.8321     0.2422 -11.692  < 2e-16 ***
# ebc_agresivo                         -0.9307     0.2165  -4.298 1.72e-05 ***
# ebc_r_viven                          -0.7146     0.2246  -3.182 0.001464 **
# ebc_susfinanzas                      -0.6083     0.1886  -3.225 0.001261 **
# ebc_sueducacion                      -0.3708     0.2137  -1.735 0.082692 .
# ebc_susalud                          -1.3226     0.2277  -5.808 6.32e-09 ***
# ebc_supais                           -0.1153     0.1687  -0.684 0.494281
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 2421.4  on 1758  degrees of freedom
# Residual deviance: 1771.6  on 1748  degrees of freedom
# AIC: 1793.6
#
# Number of Fisher Scoring iterations: 5
#                                     Estimate   Std. Error z value
# (Intercept)                          3.4770725 0.2510223   13.8516504
# ebc_pal_futuro_1_Será.amenazante     0.2746434 0.1400382    1.9612041
# ebc_pal_futuro_2_Positivo           -0.6203916 0.1677356   -3.6986273
# ebc_pal_futuro_6_Es.desesperanzador  0.9945493 0.1564121    6.3585169
# ebc_animo                           -2.8321368 0.2422268  -11.6920879
# ebc_agresivo                        -0.9307051 0.2165306   -4.2982613
# ebc_r_viven                         -0.7145768 0.2245849   -3.1817669
# ebc_susfinanzas                     -0.6083131 0.1886385   -3.2247567
# ebc_sueducacion                     -0.3708044 0.2136861   -1.7352764
# ebc_susalud                         -1.3226166 0.2277208   -5.8080632
# ebc_supais                          -0.1153105 0.1687019   -0.6835162
#                                     Pr(>|z|)
# (Intercept)                         1.243224e-43
# ebc_pal_futuro_1_Será.amenazante    4.985522e-02
# ebc_pal_futuro_2_Positivo           2.167686e-04
# ebc_pal_futuro_6_Es.desesperanzador 2.037110e-10
# ebc_animo                           1.399043e-31
# ebc_agresivo                        1.721431e-05
# ebc_r_viven                         1.463796e-03
# ebc_susfinanzas                     1.260798e-03
# ebc_sueducacion                     8.269186e-02
# ebc_susalud                         6.319966e-09
# ebc_supais                          4.942807e-01
#                         (Intercept)    ebc_pal_futuro_1_Será.amenazante
#                         32.36483605                          1.31606133
#           ebc_pal_futuro_2_Positivo ebc_pal_futuro_6_Es.desesperanzador
#                          0.53773382                          2.70350559
#                           ebc_animo                        ebc_agresivo
#                          0.05888689                          0.39427563
#                         ebc_r_viven                     ebc_susfinanzas
#                          0.48939917                          0.54426820
#                     ebc_sueducacion                         ebc_susalud
#                          0.69017895                          0.26643722
#                          ebc_supais
#                          0.89108946

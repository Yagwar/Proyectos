# %%
library(ggplot2)

# %%
data=read.csv2("datos.csv")#, sep="\t")
data$semestre=factor(data$semestre )
str(data)
# Out:
# 'data.frame':	95 obs. of  14 variables:
#  $ edad     : int  21 23 23 23 20 20 22 25 24 22 ...
#  $ Sexo     : Factor w/ 2 levels "F","M": 2 2 1 2 1 1 1 1 2 1 ...
#  $ Jornada  : Factor w/ 2 levels "D","N": 2 2 2 2 2 2 2 2 2 2 ...
#  $ prom_acum: num  3.98 4.5 4.14 3.7 4.1 3.9 4 4 3.9 4 ...
#  $ prom_sem : num  3.86 4.2 3.92 3.7 3.9 3.85 3.8 4 3.8 4 ...
#  $ semestre : Factor w/ 8 levels "1","2","3","4",..: 5 5 5 5 2 2 2 2 4 5 ...
#  $ Trabaja  : Factor w/ 2 levels "NO","SI": 2 2 2 1 2 1 2 2 2 2 ...
#  $ Putuac   : int  81 73 85 83 78 83 76 46 60 75 ...
#  $ Fact_1   : int  9 14 6 11 11 10 9 6 6 11 ...
#  $ Fact_2   : int  18 11 15 17 15 14 15 6 10 9 ...
#  $ Fact_3   : int  14 14 12 11 14 15 10 6 6 9 ...
#  $ Fact_4   : int  11 7 12 9 9 9 9 6 12 10 ...
#  $ Fact_5   : int  7 8 10 6 6 10 8 6 6 8 ...
#  $ Fact_6   : int  6 4 7 9 5 6 7 4 6 6 ...

# %%
pairs(data, pch=16, cex=0.3)
# Out:
# plot without title

# %%
ggplot(data, aes(edad)) +
  geom_density(alpha = 0.1)
# Out:
# plot without title

# %%
ggplot(data, aes(prom_sem)) +
  geom_density(alpha = 0.1)
# Out:
# plot without title

# %%
ggplot(data, aes(Putuac)) +
  geom_density(alpha = 0.1)
# Out:
# plot without title

# %%
ggplot(data, aes(Fact_1)) +
  geom_density(alpha = 0.1)
# Out:
# plot without title

# %%
ggplot(data, aes(Fact_2)) +
  geom_density(alpha = 0.1)
# Out:
# plot without title

# %%
ggplot(data, aes(Fact_3)) +
  geom_density(alpha = 0.1)
# Out:
# plot without title

# %%
ggplot(data, aes(Fact_4)) +
  geom_density(alpha = 0.1)
# Out:
# plot without title

# %%
ggplot(data, aes(Fact_5)) +
  geom_density(alpha = 0.1)
# Out:
# plot without title

# %%
ggplot(data, aes(Fact_6)) +
  geom_density(alpha = 0.1)
# Out:
# plot without title

# %%
# table(data$semestre)
# by(data$Putuac, data$semestre, mean)
# ggplot(data, aes(Putuac, fill =semestre , colour = semestre)) +
#   geom_density(alpha = 0.3)

# %%
ggplot(data, aes(Putuac, fill = Sexo, colour = Sexo)) +
  geom_density(alpha = 0.1)
# Out:
# plot without title

# %%
ggplot(data, aes(Putuac, fill = Jornada, colour =Jornada)) +
  geom_density(alpha = 0.1)
# Out:
# plot without title

# %%
ggplot(data, aes(Putuac, fill = Trabaja, colour =Trabaja)) +
  geom_density(alpha = 0.1)
# Out:
# plot without title

# %%
ggplot(data, aes(prom_acum, prom_sem))+
geom_point(alpha=0.3)
# Out:
# plot without title

# %%
ggplot(data, aes(Putuac, prom_sem))+
geom_point(alpha=0.3)
# Out:
# plot without title

# %%
# cor.test(data$prom_sem, data$Fact_1,method = "spearman")
cor.test(data$prom_acum, data$Fact_1,method = "spearman")
ggplot(data, aes(Fact_1, prom_sem))+
geom_point(alpha=0.3)
# Out:
# Warning message in cor.test.default(data$prom_acum, data$Fact_1, method = "spearman"):
# "Cannot compute exact p-value with ties"
# 	Spearman's rank correlation rho
#
# data:  data$prom_acum and data$Fact_1
# S = 185080, p-value = 0.003665
# alternative hypothesis: true rho is not equal to 0
# sample estimates:
#       rho
# -0.295341
# plot without title

# %%
ggplot(data, aes(Fact_1, fill = Sexo, colour = Sexo)) +
  geom_density(alpha = 0.1)
ggplot(data, aes(Fact_1, fill = Jornada, colour =Jornada)) +
  geom_density(alpha = 0.1)
ggplot(data, aes(Fact_1, fill = Trabaja, colour =Trabaja)) +
  geom_density(alpha = 0.1)
# Out:
# plot without title
# plot without title
# plot without title

# %%
ggplot(data, aes(Fact_2, fill = Sexo, colour = Sexo)) +
  geom_density(alpha = 0.1)
ggplot(data, aes(Fact_2, fill = Jornada, colour =Jornada)) +
  geom_density(alpha = 0.1)
ggplot(data, aes(Fact_2, fill = Trabaja, colour =Trabaja)) +
  geom_density(alpha = 0.1)
# Out:
# plot without title
# plot without title
# plot without title

# %%
ggplot(data, aes(Fact_3, fill = Sexo, colour = Sexo)) +
  geom_density(alpha = 0.1)
ggplot(data, aes(Fact_3, fill = Jornada, colour =Jornada)) +
  geom_density(alpha = 0.1)
ggplot(data, aes(Fact_3, fill = Trabaja, colour =Trabaja)) +
  geom_density(alpha = 0.1)
# Out:
# plot without title
# plot without title
# plot without title

# %%
ggplot(data, aes(Fact_4, fill = Sexo, colour = Sexo)) +
  geom_density(alpha = 0.1)
ggplot(data, aes(Fact_4, fill = Jornada, colour =Jornada)) +
  geom_density(alpha = 0.1)
ggplot(data, aes(Fact_4, fill = Trabaja, colour =Trabaja)) +
  geom_density(alpha = 0.1)
# Out:
# plot without title
# plot without title
# plot without title

# %%
ggplot(data, aes(Fact_5, fill = Sexo, colour = Sexo)) +
  geom_density(alpha = 0.1)
ggplot(data, aes(Fact_5, fill = Jornada, colour =Jornada)) +
  geom_density(alpha = 0.1)
ggplot(data, aes(Fact_5, fill = Trabaja, colour =Trabaja)) +
  geom_density(alpha = 0.1)
# Out:
# plot without title
# plot without title
# plot without title

# %%
ggplot(data, aes(Fact_6, fill = Sexo, colour = Sexo)) +
  geom_density(alpha = 0.1)
ggplot(data, aes(Fact_6, fill = Jornada, colour =Jornada)) +
  geom_density(alpha = 0.1)
ggplot(data, aes(Fact_6, fill = Trabaja, colour =Trabaja)) +
  geom_density(alpha = 0.1)
# Out:
# plot without title
# plot without title
# plot without title

# %%
cor.test(data$prom_acum,data$Putuac,method = "spearman")#, pch=16, col=rgb(0,0,0,0.3))
cor.test(data$prom_acum,data$Fact_1,method = "spearman")
cor.test(data$prom_acum,data$Fact_2,method = "spearman")
cor.test(data$prom_acum,data$Fact_3,method = "spearman")
cor.test(data$prom_acum,data$Fact_4,method = "spearman")
cor.test(data$prom_acum,data$Fact_5,method = "spearman")
cor.test(data$prom_acum,data$Fact_6,method = "spearman")
# Out:
# Warning message in cor.test.default(data$prom_acum, data$Putuac, method = "spearman"):
# "Cannot compute exact p-value with ties"
# 	Spearman's rank correlation rho
#
# data:  data$prom_acum and data$Putuac
# S = 170030, p-value = 0.06517
# alternative hypothesis: true rho is not equal to 0
# sample estimates:
#        rho
# -0.1899899
# Warning message in cor.test.default(data$prom_acum, data$Fact_1, method = "spearman"):
# "Cannot compute exact p-value with ties"
# 	Spearman's rank correlation rho
#
# data:  data$prom_acum and data$Fact_1
# S = 185080, p-value = 0.003665
# alternative hypothesis: true rho is not equal to 0
# sample estimates:
#       rho
# -0.295341
# Warning message in cor.test.default(data$prom_acum, data$Fact_2, method = "spearman"):
# "Cannot compute exact p-value with ties"
# 	Spearman's rank correlation rho
#
# data:  data$prom_acum and data$Fact_2
# S = 154810, p-value = 0.4213
# alternative hypothesis: true rho is not equal to 0
# sample estimates:
# ...

# %%
cor.test(data$prom_sem,data$Putuac,method = "spearman")#, pch=16, col=rgb(0,0,0,0.3))
cor.test(data$prom_sem,data$Fact_1,method = "spearman")
cor.test(data$prom_sem,data$Fact_2,method = "spearman")
cor.test(data$prom_sem,data$Fact_3,method = "spearman")
cor.test(data$prom_sem,data$Fact_4,method = "spearman")
cor.test(data$prom_sem,data$Fact_5,method = "spearman")
cor.test(data$prom_sem,data$Fact_6,method = "spearman")
# Out:
# Warning message in cor.test.default(data$prom_sem, data$Putuac, method = "spearman"):
# "Cannot compute exact p-value with ties"
# 	Spearman's rank correlation rho
#
# data:  data$prom_sem and data$Putuac
# S = 158320, p-value = 0.2973
# alternative hypothesis: true rho is not equal to 0
# sample estimates:
#        rho
# -0.1080548
# Warning message in cor.test.default(data$prom_sem, data$Fact_1, method = "spearman"):
# "Cannot compute exact p-value with ties"
# 	Spearman's rank correlation rho
#
# data:  data$prom_sem and data$Fact_1
# S = 165880, p-value = 0.1191
# alternative hypothesis: true rho is not equal to 0
# sample estimates:
#        rho
# -0.1610052
# Warning message in cor.test.default(data$prom_sem, data$Fact_2, method = "spearman"):
# "Cannot compute exact p-value with ties"
# 	Spearman's rank correlation rho
#
# data:  data$prom_sem and data$Fact_2
# S = 154490, p-value = 0.4335
# alternative hypothesis: true rho is not equal to 0
# sample estimates:
#         rho
# ...

# %%
cor.test(as.numeric(as.character(data$semestre)),data$Putuac,method = "spearman")#, pch=16, col=rgb(0,0,0,0.3))
cor.test(as.numeric(as.character(data$semestre)),data$Fact_1,method = "spearman")
cor.test(as.numeric(as.character(data$semestre)),data$Fact_2,method = "spearman")
cor.test(as.numeric(as.character(data$semestre)),data$Fact_3,method = "spearman")
cor.test(as.numeric(as.character(data$semestre)),data$Fact_4,method = "spearman")
cor.test(as.numeric(as.character(data$semestre)),data$Fact_5,method = "spearman")
cor.test(as.numeric(as.character(data$semestre)),data$Fact_6,method = "spearman")
# Out:
# Warning message in cor.test.default(as.numeric(as.character(data$semestre)), data$Putuac, :
# "Cannot compute exact p-value with ties"
# 	Spearman's rank correlation rho
#
# data:  as.numeric(as.character(data$semestre)) and data$Putuac
# S = 116090, p-value = 0.06884
# alternative hypothesis: true rho is not equal to 0
# sample estimates:
#       rho
# 0.1874988
# Warning message in cor.test.default(as.numeric(as.character(data$semestre)), data$Fact_1, :
# "Cannot compute exact p-value with ties"
# 	Spearman's rank correlation rho
#
# data:  as.numeric(as.character(data$semestre)) and data$Fact_1
# S = 119810, p-value = 0.118
# alternative hypothesis: true rho is not equal to 0
# sample estimates:
#       rho
# 0.1614802
# Warning message in cor.test.default(as.numeric(as.character(data$semestre)), data$Fact_2, :
# "Cannot compute exact p-value with ties"
# 	Spearman's rank correlation rho
#
# data:  as.numeric(as.character(data$semestre)) and data$Fact_2
# ...

# %%
t.test(Fact_5 ~ Sexo, data = data)
# Out:
# 	Welch Two Sample t-test
#
# data:  Fact_5 by Sexo
# t = 2.7719, df = 34.21, p-value = 0.008951
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  0.4321313 2.8047108
# sample estimates:
# mean in group F mean in group M
#        9.565789        7.947368

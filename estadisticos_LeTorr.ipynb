# %%
data=read.csv2("dat_tesis.csv")
summary(data)
data$Entidad=factor(data$Entidad,labels=c("Gubernamental","Distrital","Privada"))
data$Estrato=factor(data$Estrato,levels=c(1,2,3,4,5,6))
data$Genero=factor(data$Genero,labels=c("Femenino","Masculino"))
data$Orientación.sexual=factor(data$Orientación.sexual,labels=c("Heterosexual","Homosexual","Bisexual"))
data$Tener.pareja=factor(data$Tener.pareja,labels=c("Si","No"))
data$Tiempo=factor(data$Tiempo,labels=c("Menos de 5 meses","5 a 7 meses","8 a 12 meses","1 a 2 años","3 a 5 años","Más de 5 años"))
summary(data)
colnames(data)

dat_num=data[,c("apz_Reflexivo","apz_sensitivo","apz_intuitivo","apz_visual","apz_verbal","apz_secuencial","apz_global","atacante_fis","atacante_psico","victima_fis","victima_psico")]
dat_cat=data[,c("Entidad","Estrato","Genero","Orientación.sexual","Tener.pareja","Tiempo")]
# Out:
#       Edad          Entidad         Estrato          Genero
#  Min.   :15.00   Min.   :1.000   Min.   :1.000   Min.   :0.0000
#  1st Qu.:16.00   1st Qu.:1.000   1st Qu.:1.000   1st Qu.:0.0000
#  Median :17.00   Median :1.000   Median :2.000   Median :1.0000
#  Mean   :17.43   Mean   :1.079   Mean   :1.901   Mean   :0.5592
#  3rd Qu.:18.00   3rd Qu.:1.000   3rd Qu.:2.000   3rd Qu.:1.0000
#  Max.   :22.00   Max.   :3.000   Max.   :6.000   Max.   :1.0000
#  Orientación.sexual  Tener.pareja      Tiempo      apz_Reflexivo
#  Min.   :1.000      Min.   :1.00   Min.   :1.000   Min.   :0.0000
#  1st Qu.:1.000      1st Qu.:1.00   1st Qu.:2.000   1st Qu.:0.0000
#  Median :1.000      Median :1.00   Median :4.000   Median :0.0000
#  Mean   :1.132      Mean   :1.48   Mean   :3.382   Mean   :0.1118
#  3rd Qu.:1.000      3rd Qu.:2.00   3rd Qu.:4.250   3rd Qu.:0.0000
#  Max.   :3.000      Max.   :2.00   Max.   :6.000   Max.   :2.0000
#  apz_sensitivo    apz_intuitivo      apz_visual       apz_verbal
#  Min.   :0.0000   Min.   :0.0000   Min.   :0.0000   Min.   :0.0000
#  1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.:0.0000
#  Median :1.0000   Median :0.0000   Median :0.0000   Median :0.0000
#  Mean   :0.7829   Mean   :0.1513   Mean   :0.5592   Mean   :0.1908
#  3rd Qu.:1.0000   3rd Qu.:0.0000   3rd Qu.:1.0000   3rd Qu.:0.0000
#  Max.   :2.0000   Max.   :2.0000   Max.   :2.0000   Max.   :2.0000
#  apz_secuencial     apz_global      atacante_fis    atacante_psico
#  Min.   :0.0000   Min.   :0.0000   Min.   : 5.000   Min.   :10.00
#  1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.: 5.000   1st Qu.:16.00
#  Median :0.0000   Median :0.0000   Median : 7.000   Median :21.50
#  Mean   :0.5197   Mean   :0.1842   Mean   : 8.461   Mean   :22.44
#  3rd Qu.:1.0000   3rd Qu.:0.0000   3rd Qu.:11.000   3rd Qu.:27.00
#  Max.   :2.0000   Max.   :2.0000   Max.   :25.000   Max.   :55.00
#   victima_fis     victima_psico
#  Min.   : 0.000   Min.   : 0.000
#  1st Qu.: 0.000   1st Qu.: 0.000
#  Median : 6.000   Median : 9.000
#  Mean   : 5.658   Mean   : 8.651
#  3rd Qu.: 8.000   3rd Qu.:13.000
#  Max.   :20.000   Max.   :30.000
#       Edad                Entidad    Estrato       Genero
#  Min.   :15.00   Gubernamental:141   1:56    Femenino :67
#  1st Qu.:16.00   Distrital    : 10   2:63    Masculino:85
#  Median :17.00   Privada      :  1   3:28
#  Mean   :17.43                       4: 3
#  3rd Qu.:18.00                       5: 1
#  Max.   :22.00                       6: 1
#     Orientación.sexual Tener.pareja              Tiempo   apz_Reflexivo
#  Heterosexual:136      Si:79        Menos de 5 meses:23   Min.   :0.0000
#  Homosexual  : 12      No:73        5 a 7 meses     :25   1st Qu.:0.0000
#  Bisexual    :  4                   8 a 12 meses    :25   Median :0.0000
#                                     1 a 2 años      :41   Mean   :0.1118
#                                     3 a 5 años      :26   3rd Qu.:0.0000
#                                     Más de 5 años   :12   Max.   :2.0000
#  apz_sensitivo    apz_intuitivo      apz_visual       apz_verbal
#  Min.   :0.0000   Min.   :0.0000   Min.   :0.0000   Min.   :0.0000
#  1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.:0.0000
#  Median :1.0000   Median :0.0000   Median :0.0000   Median :0.0000
#  Mean   :0.7829   Mean   :0.1513   Mean   :0.5592   Mean   :0.1908
#  3rd Qu.:1.0000   3rd Qu.:0.0000   3rd Qu.:1.0000   3rd Qu.:0.0000
#  Max.   :2.0000   Max.   :2.0000   Max.   :2.0000   Max.   :2.0000
#  apz_secuencial     apz_global      atacante_fis    atacante_psico
#  Min.   :0.0000   Min.   :0.0000   Min.   : 5.000   Min.   :10.00
#  1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.: 5.000   1st Qu.:16.00
#  Median :0.0000   Median :0.0000   Median : 7.000   Median :21.50
#  Mean   :0.5197   Mean   :0.1842   Mean   : 8.461   Mean   :22.44
#  3rd Qu.:1.0000   3rd Qu.:0.0000   3rd Qu.:11.000   3rd Qu.:27.00
#  Max.   :2.0000   Max.   :2.0000   Max.   :25.000   Max.   :55.00
#   victima_fis     victima_psico
#  Min.   : 0.000   Min.   : 0.000
#  1st Qu.: 0.000   1st Qu.: 0.000
#  Median : 6.000   Median : 9.000
#  Mean   : 5.658   Mean   : 8.651
#  3rd Qu.: 8.000   3rd Qu.:13.000
#  Max.   :20.000   Max.   :30.000
#  [1] "Edad"               "Entidad"            "Estrato"
#  [4] "Genero"             "Orientación.sexual" "Tener.pareja"
#  [7] "Tiempo"             "apz_Reflexivo"      "apz_sensitivo"
# [10] "apz_intuitivo"      "apz_visual"         "apz_verbal"
# [13] "apz_secuencial"     "apz_global"         "atacante_fis"
# [16] "atacante_psico"     "victima_fis"        "victima_psico"

# %%
pairs(dat_num, pch=16, cex=.7)
# Out:
# plot without title

# %%
for (clmn_indx in 2:(length(colnames(dat_num))-1)){
    for (clmn_indx_2 in (clmn_indx+1):(length(colnames(dat_num)))){
        crr_tst=cor.test(dat_num[,clmn_indx],dat_num[,clmn_indx_2])
        print(paste("Correlación entre", colnames(dat_num)[clmn_indx],"y",colnames(dat_num)[clmn_indx_2],
                    "r(x,y)=",round(crr_tst$estimate,3),
                    "valor p=",round(crr_tst$p.value,3),
                    "significativo a 0.05=",crr_tst$p.value<=.05))
        print(crr_tst)
#         jpeg(paste(colnames(dat_num)[clmn_indx],"-",colnames(dat_num)[clmn_indx_2],".jpg", sep=""),width = 600, height = 600)
        plot(dat_num[,clmn_indx], dat_num[,clmn_indx_2], pch=16, xlab=colnames(dat_num)[clmn_indx],ylab=colnames(dat_num)[clmn_indx_2])
        title(main=paste("Correlación entre", colnames(dat_num)[clmn_indx],"y",colnames(dat_num)[clmn_indx_2]),
              sub=paste("r(x,y)=",round(crr_tst$estimate,3),"valor p=",round(crr_tst$p.value,3)))
        abline(lm(dat_num[,clmn_indx_2]~ dat_num[,clmn_indx]))
#         dev.off()
    }
}
# Out:
# [1] "Correlación entre apz_sensitivo y apz_intuitivo r(x,y)= -0.366 valor p= 0 significativo a 0.05= TRUE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = -4.8205, df = 150, p-value = 0.000003478
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.4964984 -0.2198659
# sample estimates:
#        cor
# -0.3662469
#
# [1] "Correlación entre apz_sensitivo y apz_visual r(x,y)= 0.22 valor p= 0.006 significativo a 0.05= TRUE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = 2.766, df = 150, p-value = 0.006388
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.06331526 0.36663770
# sample estimates:
#       cor
# 0.2202954
# Plot with title "Correlación entre apz_sensitivo y apz_intuitivo"
# [1] "Correlación entre apz_sensitivo y apz_verbal r(x,y)= -0.105 valor p= 0.197 significativo a 0.05= FALSE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = -1.2957, df = 150, p-value = 0.1971
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.2600490  0.0549167
# sample estimates:
#        cor
# -0.1052038
# Plot with title "Correlación entre apz_sensitivo y apz_visual"
# [1] "Correlación entre apz_sensitivo y apz_secuencial r(x,y)= 0.08 valor p= 0.329 significativo a 0.05= FALSE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = 0.97835, df = 150, p-value = 0.3295
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.08059405  0.23583933
# sample estimates:
#        cor
# 0.07962833
# Plot with title "Correlación entre apz_sensitivo y apz_verbal"
# [1] "Correlación entre apz_sensitivo y apz_global r(x,y)= -0.075 valor p= 0.356 significativo a 0.05= FALSE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = -0.92529, df = 150, p-value = 0.3563
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.23175596  0.08488396
# sample estimates:
#         cor
# -0.07533479
# Plot with title "Correlación entre apz_sensitivo y apz_secuencial"
# [1] "Correlación entre apz_sensitivo y atacante_fis r(x,y)= -0.067 valor p= 0.412 significativo a 0.05= FALSE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = -0.82208, df = 150, p-value = 0.4123
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.22378655  0.09322279
# sample estimates:
#         cor
# -0.06697185
# Plot with title "Correlación entre apz_sensitivo y apz_global"
# [1] "Correlación entre apz_sensitivo y atacante_psico r(x,y)= -0.018 valor p= 0.829 significativo a 0.05= FALSE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = -0.21609, df = 150, p-value = 0.8292
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.1763460  0.1419589
# sample estimates:
#         cor
# -0.01764053
# Plot with title "Correlación entre apz_sensitivo y atacante_fis"
# [1] "Correlación entre apz_sensitivo y victima_fis r(x,y)= -0.068 valor p= 0.406 significativo a 0.05= FALSE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = -0.83297, df = 150, p-value = 0.4062
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.22462883  0.09234356
# sample estimates:
#         cor
# -0.06785469
# Plot with title "Correlación entre apz_sensitivo y atacante_psico"
# [1] "Correlación entre apz_sensitivo y victima_psico r(x,y)= -0.08 valor p= 0.33 significativo a 0.05= FALSE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = -0.97723, df = 150, p-value = 0.33
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.23575341  0.08068444
# sample estimates:
#         cor
# -0.07953793
# Plot with title "Correlación entre apz_sensitivo y victima_fis"
# [1] "Correlación entre apz_intuitivo y apz_visual r(x,y)= -0.132 valor p= 0.105 significativo a 0.05= FALSE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = -1.6332, df = 150, p-value = 0.1045
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.28537355  0.02760365
# sample estimates:
#        cor
# -0.1321779
# Plot with title "Correlación entre apz_sensitivo y victima_psico"
# [1] "Correlación entre apz_intuitivo y apz_verbal r(x,y)= 0.053 valor p= 0.516 significativo a 0.05= FALSE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = 0.6514, df = 150, p-value = 0.5158
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.1069935  0.2105324
# sample estimates:
#        cor
# 0.05311183
# Plot with title "Correlación entre apz_intuitivo y apz_visual"
# [1] "Correlación entre apz_intuitivo y apz_secuencial r(x,y)= -0.022 valor p= 0.787 significativo a 0.05= FALSE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = -0.27026, df = 150, p-value = 0.7873
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.1806279  0.1376225
# sample estimates:
#        cor
# -0.0220616
# Plot with title "Correlación entre apz_intuitivo y apz_verbal"
# [1] "Correlación entre apz_intuitivo y apz_global r(x,y)= 0.061 valor p= 0.459 significativo a 0.05= FALSE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = 0.74257, df = 150, p-value = 0.4589
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.09964098  0.21762369
# sample estimates:
#        cor
# 0.06051974
# Plot with title "Correlación entre apz_intuitivo y apz_secuencial"
# [1] "Correlación entre apz_intuitivo y atacante_fis r(x,y)= -0.019 valor p= 0.816 significativo a 0.05= FALSE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = -0.23367, df = 150, p-value = 0.8156
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.1777368  0.1405516
# sample estimates:
#        cor
# -0.0190759
# Plot with title "Correlación entre apz_intuitivo y apz_global"
# [1] "Correlación entre apz_intuitivo y atacante_psico r(x,y)= -0.039 valor p= 0.633 significativo a 0.05= FALSE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = -0.47837, df = 150, p-value = 0.6331
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.1970054  0.1209232
# sample estimates:
#        cor
# -0.0390288
# Plot with title "Correlación entre apz_intuitivo y atacante_fis"
# [1] "Correlación entre apz_intuitivo y victima_fis r(x,y)= -0.041 valor p= 0.62 significativo a 0.05= FALSE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = -0.49687, df = 150, p-value = 0.62
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.1984562  0.1194353
# sample estimates:
#         cor
# -0.04053617
# Plot with title "Correlación entre apz_intuitivo y atacante_psico"
# [1] "Correlación entre apz_intuitivo y victima_psico r(x,y)= -0.074 valor p= 0.365 significativo a 0.05= FALSE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = -0.90854, df = 150, p-value = 0.365
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.23046522  0.08623755
# sample estimates:
#         cor
# -0.07397881
# Plot with title "Correlación entre apz_intuitivo y victima_fis"
# [1] "Correlación entre apz_visual y apz_verbal r(x,y)= -0.332 valor p= 0 significativo a 0.05= TRUE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = -4.3048, df = 150, p-value = 0.00003004
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.4661878 -0.1820049
# sample estimates:
#        cor
# -0.3315974
# Plot with title "Correlación entre apz_intuitivo y victima_psico"
# [1] "Correlación entre apz_visual y apz_secuencial r(x,y)= 0.213 valor p= 0.009 significativo a 0.05= TRUE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = 2.6662, df = 150, p-value = 0.008512
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.05539061 0.35973404
# sample estimates:
#       cor
# 0.2127155
# Plot with title "Correlación entre apz_visual y apz_verbal"
# [1] "Correlación entre apz_visual y apz_global r(x,y)= -0.227 valor p= 0.005 significativo a 0.05= TRUE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = -2.8548, df = 150, p-value = 0.004916
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.37274046 -0.07035256
# sample estimates:
#        cor
# -0.2270107
# Plot with title "Correlación entre apz_visual y apz_secuencial"
# [1] "Correlación entre apz_visual y atacante_fis r(x,y)= -0.155 valor p= 0.056 significativo a 0.05= FALSE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = -1.9221, df = 150, p-value = 0.05649
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.306669973  0.004267456
# sample estimates:
#        cor
# -0.1550386
# Plot with title "Correlación entre apz_visual y apz_global"
# [1] "Correlación entre apz_visual y atacante_psico r(x,y)= -0.152 valor p= 0.061 significativo a 0.05= FALSE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = -1.8892, df = 150, p-value = 0.0608
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.304264544  0.006920352
# sample estimates:
#        cor
# -0.1524483
# Plot with title "Correlación entre apz_visual y atacante_fis"
# [1] "Correlación entre apz_visual y victima_fis r(x,y)= -0.203 valor p= 0.012 significativo a 0.05= TRUE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = -2.5417, df = 150, p-value = 0.01205
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.35104140 -0.04546665
# sample estimates:
#        cor
# -0.2031965
# Plot with title "Correlación entre apz_visual y atacante_psico"
# [1] "Correlación entre apz_visual y victima_psico r(x,y)= -0.212 valor p= 0.009 significativo a 0.05= TRUE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = -2.6626, df = 150, p-value = 0.008601
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.35947769 -0.05509708
# sample estimates:
#        cor
# -0.2124344
# Plot with title "Correlación entre apz_visual y victima_fis"
# [1] "Correlación entre apz_verbal y apz_secuencial r(x,y)= 0.103 valor p= 0.205 significativo a 0.05= FALSE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = 1.2725, df = 150, p-value = 0.2052
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.05679619  0.25829031
# sample estimates:
#       cor
# 0.1033389
# Plot with title "Correlación entre apz_visual y victima_psico"
# [1] "Correlación entre apz_verbal y apz_global r(x,y)= -0.042 valor p= 0.609 significativo a 0.05= FALSE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = -0.51207, df = 150, p-value = 0.6094
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.1996469  0.1182129
# sample estimates:
#         cor
# -0.04177395
# Plot with title "Correlación entre apz_verbal y apz_secuencial"
# [1] "Correlación entre apz_verbal y atacante_fis r(x,y)= 0.093 valor p= 0.255 significativo a 0.05= FALSE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = 1.1419, df = 150, p-value = 0.2553
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.06736156  0.24836473
# sample estimates:
#       cor
# 0.0928347
# Plot with title "Correlación entre apz_verbal y apz_global"
# [1] "Correlación entre apz_verbal y atacante_psico r(x,y)= 0.159 valor p= 0.05 significativo a 0.05= TRUE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = 1.978, df = 150, p-value = 0.04976
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.0002433831 0.3107509343
# sample estimates:
#       cor
# 0.1594379
# Plot with title "Correlación entre apz_verbal y atacante_fis"
# [1] "Correlación entre apz_verbal y victima_fis r(x,y)= 0.277 valor p= 0.001 significativo a 0.05= TRUE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = 3.5324, df = 150, p-value = 0.0005476
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.1233631 0.4178857
# sample estimates:
#       cor
# 0.2771213
# Plot with title "Correlación entre apz_verbal y atacante_psico"
# [1] "Correlación entre apz_verbal y victima_psico r(x,y)= 0.212 valor p= 0.009 significativo a 0.05= TRUE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = 2.6628, df = 150, p-value = 0.008596
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.05511337 0.35949191
# sample estimates:
#     cor
# 0.21245
# Plot with title "Correlación entre apz_verbal y victima_fis"
# [1] "Correlación entre apz_secuencial y apz_global r(x,y)= -0.318 valor p= 0 significativo a 0.05= TRUE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = -4.1066, df = 150, p-value = 0.00006575
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.4541267 -0.1671701
# sample estimates:
#      cor
# -0.31791
# Plot with title "Correlación entre apz_verbal y victima_psico"
# [1] "Correlación entre apz_secuencial y atacante_fis r(x,y)= -0.123 valor p= 0.132 significativo a 0.05= FALSE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = -1.5133, df = 150, p-value = 0.1323
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.27642831  0.03730496
# sample estimates:
#       cor
# -0.122624
# Plot with title "Correlación entre apz_secuencial y apz_global"
# [1] "Correlación entre apz_secuencial y atacante_psico r(x,y)= -0.152 valor p= 0.062 significativo a 0.05= FALSE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = -1.8787, df = 150, p-value = 0.06222
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.303498650  0.007764122
# sample estimates:
#       cor
# -0.151624
# Plot with title "Correlación entre apz_secuencial y atacante_fis"
# [1] "Correlación entre apz_secuencial y victima_fis r(x,y)= -0.146 valor p= 0.073 significativo a 0.05= FALSE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = -1.8069, df = 150, p-value = 0.07279
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.29822072  0.01356669
# sample estimates:
#        cor
# -0.1459492
# Plot with title "Correlación entre apz_secuencial y atacante_psico"
# [1] "Correlación entre apz_secuencial y victima_psico r(x,y)= -0.127 valor p= 0.119 significativo a 0.05= FALSE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = -1.566, df = 150, p-value = 0.1195
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.2803707  0.0330366
# sample estimates:
#        cor
# -0.1268312
# Plot with title "Correlación entre apz_secuencial y victima_fis"
# [1] "Correlación entre apz_global y atacante_fis r(x,y)= -0.062 valor p= 0.445 significativo a 0.05= FALSE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = -0.76536, df = 150, p-value = 0.4453
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.21939239  0.09780169
# sample estimates:
#         cor
# -0.06237012
# Plot with title "Correlación entre apz_secuencial y victima_psico"
# [1] "Correlación entre apz_global y atacante_psico r(x,y)= 0.046 valor p= 0.577 significativo a 0.05= FALSE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = 0.55874, df = 150, p-value = 0.5772
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.1144577  0.2032991
# sample estimates:
#        cor
# 0.04557339
# Plot with title "Correlación entre apz_global y atacante_fis"
# [1] "Correlación entre apz_global y victima_fis r(x,y)= 0.105 valor p= 0.197 significativo a 0.05= FALSE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = 1.2954, df = 150, p-value = 0.1972
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.05493447  0.26003242
# sample estimates:
#       cor
# 0.1051861
# Plot with title "Correlación entre apz_global y atacante_psico"
# [1] "Correlación entre apz_global y victima_psico r(x,y)= 0.137 valor p= 0.092 significativo a 0.05= FALSE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = 1.6946, df = 150, p-value = 0.09222
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.02263394  0.28993491
# sample estimates:
#       cor
# 0.1370606
# Plot with title "Correlación entre apz_global y victima_fis"
# [1] "Correlación entre atacante_fis y atacante_psico r(x,y)= 0.702 valor p= 0 significativo a 0.05= TRUE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = 12.072, df = 150, p-value < 0.00000000000000022
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.6110885 0.7746252
# sample estimates:
#       cor
# 0.7019951
# Plot with title "Correlación entre apz_global y victima_psico"
# [1] "Correlación entre atacante_fis y victima_fis r(x,y)= 0.309 valor p= 0 significativo a 0.05= TRUE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = 3.9774, df = 150, p-value = 0.0001081
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.1574100 0.4461337
# sample estimates:
#       cor
# 0.3088705
# Plot with title "Correlación entre atacante_fis y atacante_psico"
# [1] "Correlación entre atacante_fis y victima_psico r(x,y)= 0.283 valor p= 0 significativo a 0.05= TRUE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = 3.6203, df = 150, p-value = 0.0004018
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.1301428 0.4235565
# sample estimates:
#       cor
# 0.2834703
# Plot with title "Correlación entre atacante_fis y victima_fis"
# [1] "Correlación entre atacante_psico y victima_fis r(x,y)= 0.549 valor p= 0 significativo a 0.05= TRUE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = 8.0472, df = 150, p-value = 0.0000000000002387
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.4272758 0.6513801
# sample estimates:
#       cor
# 0.5491237
# Plot with title "Correlación entre atacante_fis y victima_psico"
# [1] "Correlación entre atacante_psico y victima_psico r(x,y)= 0.546 valor p= 0 significativo a 0.05= TRUE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = 7.9824, df = 150, p-value = 0.0000000000003453
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.4236494 0.6488236
# sample estimates:
#       cor
# 0.5460234
# Plot with title "Correlación entre atacante_psico y victima_fis"
# [1] "Correlación entre victima_fis y victima_psico r(x,y)= 0.893 valor p= 0 significativo a 0.05= TRUE"
#
# 	Pearson's product-moment correlation
#
# data:  dat_num[, clmn_indx] and dat_num[, clmn_indx_2]
# t = 24.277, df = 150, p-value < 0.00000000000000022
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.8551671 0.9210957
# sample estimates:
#       cor
# 0.8928168
# Plot with title "Correlación entre atacante_psico y victima_psico"
# Plot with title "Correlación entre victima_fis y victima_psico"

# %% [markdown]
# # Relaciones entre variables categóricas

# %%
factores=c("Entidad","Estrato","Genero","Orientación.sexual","Tener.pareja","Tiempo")
vars_deps=c("Edad","apz_Reflexivo","apz_sensitivo","apz_intuitivo","apz_visual","apz_verbal","apz_secuencial","apz_global","atacante_fis","atacante_psico","victima_fis","victima_psico")

# %%
for (factor in factores){
    for (var_dep in vars_deps){
        print("************************************************************")
        print("************************************************************")
        print("ANÁLISIS")
        print(paste("Variable categórica:",factor))
        print(paste("Variable numérica:",var_dep))
        print("************************************************************")
        lvn_tst=leveneTest(unlist(data[var_dep]) ~ unlist(data[factor]))
        aov_test <- aov(unlist(data[var_dep]) ~ unlist(data[factor]))
        p_val_lev=lvn_tst["group",'Pr(>F)']
        p_val_aov=summary(aov_test)[[1]][[1,"Pr(>F)"]]
        if (p_val_lev>.05){
            print(paste("prueba de levene, valor-p =", round(p_val_lev,3), ". Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"))
#             print(lvn_tst)
        }else{
            print(paste("prueba de levene, valor-p =", round(p_val_lev,3), ". Es menor a 0.05; no se asume homogeneidad de varianzas. No es viable comparar las medias de los grupos" ))
#             print(lvn_tst)
        }
        if (p_val_aov<.05){
            print(paste("ANOVA de una vía, valor-p =", round(p_val_aov,3), ". Es menor a 0.05; Se encuentran diferencias estadísticamente significativas entre los grupos" ))
            print(summary(aov_test))
            print(TukeyHSD(aov_test))
        }else{
            print(paste("ANOVA de una vía, valor-p =", round(p_val_aov,3), ". Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas" ))
            print(summary(aov_test))
        }
    }
}
# Out:
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Entidad"
# [1] "Variable numérica: Edad"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.194 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.869 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   2    0.9  0.4455   0.141  0.869
# Residuals            149  470.5  3.1574
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Entidad"
# [1] "Variable numérica: apz_Reflexivo"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.523 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.523 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   2  0.148 0.07416   0.652  0.523
# Residuals            149 16.950 0.11376
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Entidad"
# [1] "Variable numérica: apz_sensitivo"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.427 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.428 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   2   1.00  0.4979   0.854  0.428
# Residuals            149  86.84  0.5828
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Entidad"
# [1] "Variable numérica: apz_intuitivo"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.026 . Es menor a 0.05; no se asume homogeneidad de varianzas. No es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.026 . Es menor a 0.05; Se encuentran diferencias estadísticamente significativas entre los grupos"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   2  1.318  0.6588   3.746 0.0259 *
# Residuals            149 26.202  0.1759
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = unlist(data[var_dep]) ~ unlist(data[factor]))
#
# $`unlist(data[factor])`
#                               diff         lwr       upr     p adj
# Distrital-Gubernamental  0.3723404  0.04746269 0.6972182 0.0202487
# Privada-Gubernamental   -0.1276596 -1.12392634 0.8686072 0.9505575
# Privada-Distrital       -0.5000000 -1.54120770 0.5412077 0.4929989
#
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Entidad"
# [1] "Variable numérica: apz_visual"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.321 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.053 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   2   2.76  1.3804   2.994 0.0531 .
# Residuals            149  68.71  0.4611
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Entidad"
# [1] "Variable numérica: apz_verbal"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.326 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.326 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   2   0.50  0.2499   1.129  0.326
# Residuals            149  32.97  0.2213
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Entidad"
# [1] "Variable numérica: apz_secuencial"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.424 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.013 . Es menor a 0.05; Se encuentran diferencias estadísticamente significativas entre los grupos"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   2   3.84  1.9176   4.457 0.0132 *
# Residuals            149  64.11  0.4302
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = unlist(data[var_dep]) ~ unlist(data[factor]))
#
# $`unlist(data[factor])`
#                              diff         lwr       upr     p adj
# Distrital-Gubernamental 0.4177305 -0.09042883 0.9258898 0.1295049
# Privada-Gubernamental   1.5177305 -0.04058575 3.0760467 0.0580757
# Privada-Distrital       1.1000000 -0.52861086 2.7286109 0.2492677
#
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Entidad"
# [1] "Variable numérica: apz_global"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.762 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.762 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   2  0.112 0.05616   0.272  0.762
# Residuals            149 30.730 0.20624
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Entidad"
# [1] "Variable numérica: atacante_fis"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.087 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.347 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   2   29.7   14.85   1.066  0.347
# Residuals            149 2076.1   13.93
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Entidad"
# [1] "Variable numérica: atacante_psico"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.134 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.218 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   2    177   88.54   1.541  0.218
# Residuals            149   8560   57.45
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Entidad"
# [1] "Variable numérica: victima_fis"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.346 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.143 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   2   70.7   35.35   1.973  0.143
# Residuals            149 2669.5   17.92
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Entidad"
# [1] "Variable numérica: victima_psico"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.307 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.12 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   2    179   89.41   2.151   0.12
# Residuals            149   6194   41.57
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Estrato"
# [1] "Variable numérica: Edad"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.655 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.268 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   5   20.1   4.015   1.299  0.268
# Residuals            146  451.3   3.091
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Estrato"
# [1] "Variable numérica: apz_Reflexivo"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.792 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.792 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   5  0.275 0.05505   0.478  0.792
# Residuals            146 16.823 0.11523
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Estrato"
# [1] "Variable numérica: apz_sensitivo"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.2 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.431 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   5   2.86  0.5715   0.982  0.431
# Residuals            146  84.98  0.5820
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Estrato"
# [1] "Variable numérica: apz_intuitivo"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.318 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.022 . Es menor a 0.05; Se encuentran diferencias estadísticamente significativas entre los grupos"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   5  2.341  0.4682   2.715 0.0223 *
# Residuals            146 25.179  0.1725
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = unlist(data[var_dep]) ~ unlist(data[factor]))
#
# $`unlist(data[factor])`
#                           diff         lwr       upr     p adj
# 2-1  0.03571428571428569842539 -0.18454585 0.2559744 0.9971458
# 3-1  0.07142857142857142460635 -0.20615472 0.3490119 0.9761322
# 4-1  0.89285714285714279370154  0.18213791 1.6035764 0.0051951
# 5-1 -0.10714285714285715078731 -1.31710036 1.1028146 0.9998487
# 6-1 -0.10714285714285723405403 -1.31710036 1.1028146 0.9998487
# 3-2  0.03571428571428572618096 -0.23668007 0.3081086 0.9989700
# 4-2  0.85714285714285709527616  0.14843415 1.5658516 0.0081641
# 5-2 -0.14285714285714284921269 -1.35163477 1.0659205 0.9993776
# 6-2 -0.14285714285714293247942 -1.35163477 1.0659205 0.9993776
# 4-3  0.82142857142857139685077  0.09286424 1.5499929 0.0173103
# 5-3 -0.17857142857142857539365 -1.39909645 1.0419536 0.9982530
# 6-3 -0.17857142857142865866038 -1.39909645 1.0419536 0.9982530
# 5-4 -1.00000000000000000000000 -2.38482875 0.3848287 0.3006929
# 6-4 -1.00000000000000000000000 -2.38482875 0.3848287 0.3006929
# 6-5 -0.00000000000000008326673 -1.69606191 1.6960619 1.0000000
#
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Estrato"
# [1] "Variable numérica: apz_visual"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.314 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.012 . Es menor a 0.05; Se encuentran diferencias estadísticamente significativas entre los grupos"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   5   6.73  1.3454   3.034 0.0123 *
# Residuals            146  64.74  0.4434
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = unlist(data[var_dep]) ~ unlist(data[factor]))
#
# $`unlist(data[factor])`
#           diff        lwr        upr     p adj
# 2-1 -0.2837302 -0.6369190 0.06945868 0.1927704
# 3-1 -0.2321429 -0.6772498 0.21296410 0.6608674
# 4-1  0.6369048 -0.5027391 1.77654858 0.5907075
# 5-1  0.3035714 -1.6366048 2.24374769 0.9975914
# 6-1  1.3035714 -0.6366048 3.24374769 0.3820336
# 3-2  0.0515873 -0.3851992 0.48837377 0.9993796
# 4-2  0.9206349 -0.2157850 2.05705484 0.1851693
# 5-2  0.5873016 -1.3509827 2.52558592 0.9518994
# 6-2  1.5873016 -0.3509827 3.52558592 0.1756235
# 4-3  0.8690476 -0.2992110 2.03730619 0.2687510
# 5-3  0.5357143 -1.4214071 2.49283564 0.9687597
# 6-3  1.5357143 -0.4214071 3.49283564 0.2148112
# 5-4 -0.3333333 -2.5539170 1.88725034 0.9980244
# 6-4  0.6666667 -1.5539170 2.88725034 0.9537171
# 6-5  1.0000000 -1.7196485 3.71964846 0.8955792
#
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Estrato"
# [1] "Variable numérica: apz_verbal"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.14 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.14 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   5   1.83  0.3668   1.693   0.14
# Residuals            146  31.63  0.2167
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Estrato"
# [1] "Variable numérica: apz_secuencial"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.473 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.004 . Es menor a 0.05; Se encuentran diferencias estadísticamente significativas entre los grupos"
#                       Df Sum Sq Mean Sq F value  Pr(>F)
# unlist(data[factor])   5   7.59  1.5187   3.674 0.00367 **
# Residuals            146  60.35  0.4133
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = unlist(data[var_dep]) ~ unlist(data[factor]))
#
# $`unlist(data[factor])`
#            diff         lwr       upr     p adj
# 2-1 -0.06944444 -0.41044022 0.2715513 0.9916917
# 3-1  0.16071429 -0.26902634 0.5904549 0.8886319
# 4-1  1.18452381  0.08422367 2.2848239 0.0268782
# 5-1  0.51785714 -1.35533883 2.3910531 0.9673937
# 6-1  1.51785714 -0.35533883 3.3910531 0.1849652
# 3-2  0.23015873 -0.19154866 0.6518661 0.6155137
# 4-2  1.25396825  0.15678071 2.3511558 0.0150869
# 5-2  0.58730159 -1.28406777 2.4586709 0.9443580
# 6-2  1.58730159 -0.28406777 3.4586709 0.1464415
# 4-3  1.02380952 -0.10411751 2.1517366 0.0986310
# 5-3  0.35714286 -1.53241322 2.2466989 0.9941232
# 6-3  1.35714286 -0.53241322 3.2466989 0.3066026
# 5-4 -0.66666667 -2.81058960 1.4772563 0.9464332
# 6-4  0.33333333 -1.81058960 2.4772563 0.9976631
# 6-5  1.00000000 -1.62575862 3.6257586 0.8807475
#
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Estrato"
# [1] "Variable numérica: apz_global"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.652 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.652 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   5  0.685  0.1371   0.664  0.652
# Residuals            146 30.157  0.2066
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Estrato"
# [1] "Variable numérica: atacante_fis"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.296 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.037 . Es menor a 0.05; Se encuentran diferencias estadísticamente significativas entre los grupos"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   5  162.7   32.54   2.445 0.0368 *
# Residuals            146 1943.1   13.31
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = unlist(data[var_dep]) ~ unlist(data[factor]))
#
# $`unlist(data[factor])`
#           diff         lwr       upr     p adj
# 2-1  0.9761905  -0.9587313  2.911112 0.6920017
# 3-1  2.8928571   0.4543680  5.331346 0.0101436
# 4-1  1.1666667  -5.0767968  7.410130 0.9944284
# 5-1 -1.5000000 -12.1291277  9.129128 0.9985311
# 6-1  1.5000000  -9.1291277 12.129128 0.9985311
# 3-2  1.9166667  -0.4762392  4.309573 0.1954667
# 4-2  0.1904762  -6.0353254  6.416278 0.9999992
# 5-2 -2.4761905 -13.0949534  8.142572 0.9845964
# 6-2  0.5238095 -10.0949534 11.142572 0.9999917
# 4-3 -1.7261905  -8.1264180  4.674037 0.9706960
# 5-3 -4.3928571 -15.1148175  6.329103 0.8442428
# 6-3 -1.3928571 -12.1148175  9.329103 0.9990150
# 5-4 -2.6666667 -14.8319879  9.498655 0.9883582
# 6-4  0.3333333 -11.8319879 12.498655 0.9999996
# 6-5  3.0000000 -11.8994148 17.899415 0.9921165
#
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Estrato"
# [1] "Variable numérica: atacante_psico"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.433 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.057 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   5    613  122.68   2.205 0.0569 .
# Residuals            146   8124   55.64
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Estrato"
# [1] "Variable numérica: victima_fis"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.828 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0 . Es menor a 0.05; Se encuentran diferencias estadísticamente significativas entre los grupos"
#                       Df Sum Sq Mean Sq F value   Pr(>F)
# unlist(data[factor])   5  416.6   83.33   5.236 0.000188 ***
# Residuals            146 2323.6   15.91
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = unlist(data[var_dep]) ~ unlist(data[factor]))
#
# $`unlist(data[factor])`
#                         diff        lwr        upr     p adj
# 2-1  0.700396825396825128962  -1.415525  2.8163189 0.9308742
# 3-1 -3.410714285714285587403  -6.077309 -0.7441191 0.0041458
# 4-1 -2.458333333333332593185  -9.285835  4.3691687 0.9036607
# 5-1 -6.125000000000000000000 -17.748419  5.4984188 0.6508344
# 6-1 -6.124999999999998223643 -17.748419  5.4984188 0.6508344
# 3-2 -4.111111111111110716365  -6.727859 -1.4943633 0.0001696
# 4-2 -3.158730158730157722147  -9.966918  3.6494578 0.7622927
# 5-2 -6.825396825396825128962 -18.437481  4.7866876 0.5356749
# 6-2 -6.825396825396823352605 -18.437481  4.7866876 0.5356749
# 4-3  0.952380952380952994218  -6.046549  7.9513114 0.9987675
# 5-3 -2.714285714285714412597 -14.439221  9.0106496 0.9850935
# 6-3 -2.714285714285712636240 -14.439221  9.0106496 0.9850935
# 5-4 -3.666666666666667406815 -16.969981  9.6366473 0.9678162
# 6-4 -3.666666666666665630459 -16.969981  9.6366473 0.9678162
# 6-5  0.000000000000001776357 -16.293166 16.2931655 1.0000000
#
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Estrato"
# [1] "Variable numérica: victima_psico"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.744 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.003 . Es menor a 0.05; Se encuentran diferencias estadísticamente significativas entre los grupos"
#                       Df Sum Sq Mean Sq F value  Pr(>F)
# unlist(data[factor])   5    733  146.66   3.797 0.00291 **
# Residuals            146   5639   38.62
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = unlist(data[var_dep]) ~ unlist(data[factor]))
#
# $`unlist(data[factor])`
#                          diff        lwr        upr     p adj
# 2-1   1.246031746031745157666  -2.050293  4.5423562 0.8840434
# 3-1  -4.000000000000000000000  -8.154200  0.1541998 0.0663256
# 4-1  -4.071428571428572951163 -14.707767  6.5649094 0.8784595
# 5-1  -9.071428571428574727520 -27.179166  9.0363084 0.6983752
# 6-1  -9.071428571428571174806 -27.179166  9.0363084 0.6983752
# 3-2  -5.246031746031745157666  -9.322576 -1.1694874 0.0038331
# 4-2  -5.317460317460318108829 -15.923710  5.2887889 0.6976899
# 5-2 -10.317460317460319885186 -28.407540  7.7726192 0.5688702
# 6-2 -10.317460317460316332472 -28.407540  7.7726192 0.5688702
# 4-3  -0.071428571428572951163 -10.974829 10.8319720 1.0000000
# 5-3  -5.071428571428574727520 -23.337315 13.1944576 0.9667865
# 6-3  -5.071428571428571174806 -23.337315 13.1944576 0.9667865
# 5-4  -5.000000000000001776357 -25.724790 15.7247897 0.9820608
# 6-4  -4.999999999999998223643 -25.724790 15.7247897 0.9820608
# 6-5   0.000000000000003552714 -25.382580 25.3825799 1.0000000
#
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Genero"
# [1] "Variable numérica: Edad"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.024 . Es menor a 0.05; no se asume homogeneidad de varianzas. No es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.004 . Es menor a 0.05; Se encuentran diferencias estadísticamente significativas entre los grupos"
#                       Df Sum Sq Mean Sq F value  Pr(>F)
# unlist(data[factor])   1   25.5  25.497   8.578 0.00393 **
# Residuals            150  445.8   2.972
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = unlist(data[var_dep]) ~ unlist(data[factor]))
#
# $`unlist(data[factor])`
#                          diff       lwr        upr     p adj
# Masculino-Femenino -0.8249342 -1.381463 -0.2684056 0.0039335
#
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Genero"
# [1] "Variable numérica: apz_Reflexivo"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.028 . Es menor a 0.05; no se asume homogeneidad de varianzas. No es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.028 . Es menor a 0.05; Se encuentran diferencias estadísticamente significativas entre los grupos"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   1  0.542  0.5421   4.911 0.0282 *
# Residuals            150 16.557  0.1104
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = unlist(data[var_dep]) ~ unlist(data[factor]))
#
# $`unlist(data[factor])`
#                          diff       lwr         upr     p adj
# Masculino-Femenino -0.1202809 -0.227527 -0.01303488 0.0281933
#
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Genero"
# [1] "Variable numérica: apz_sensitivo"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.967 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.461 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   1   0.32  0.3184   0.546  0.461
# Residuals            150  87.52  0.5834
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Genero"
# [1] "Variable numérica: apz_intuitivo"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.049 . Es menor a 0.05; no se asume homogeneidad de varianzas. No es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.049 . Es menor a 0.05; Se encuentran diferencias estadísticamente significativas entre los grupos"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   1  0.705  0.7046   3.942 0.0489 *
# Residuals            150 26.815  0.1788
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = unlist(data[var_dep]) ~ unlist(data[factor]))
#
# $`unlist(data[factor])`
#                         diff          lwr       upr     p adj
# Masculino-Femenino 0.1371378 0.0006527688 0.2736229 0.0489281
#
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Genero"
# [1] "Variable numérica: apz_visual"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.9 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.9 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   1   0.01  0.0076   0.016    0.9
# Residuals            150  71.46  0.4764
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Genero"
# [1] "Variable numérica: apz_verbal"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.674 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.674 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   1   0.04 0.03954   0.177  0.674
# Residuals            150  33.43 0.22285
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Genero"
# [1] "Variable numérica: apz_secuencial"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.056 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.056 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   1   1.63  1.6332   3.694 0.0565 .
# Residuals            150  66.31  0.4421
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Genero"
# [1] "Variable numérica: apz_global"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.813 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.813 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   1  0.012 0.01155   0.056  0.813
# Residuals            150 30.831 0.20554
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Genero"
# [1] "Variable numérica: atacante_fis"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.608 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.823 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   1    0.7   0.706    0.05  0.823
# Residuals            150 2105.1  14.034
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Genero"
# [1] "Variable numérica: atacante_psico"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.98 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.06 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   1    204  204.19   3.589 0.0601 .
# Residuals            150   8533   56.89
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Genero"
# [1] "Variable numérica: victima_fis"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0 . Es menor a 0.05; no se asume homogeneidad de varianzas. No es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0 . Es menor a 0.05; Se encuentran diferencias estadísticamente significativas entre los grupos"
#                       Df Sum Sq Mean Sq F value         Pr(>F)
# unlist(data[factor])   1  624.1   624.1   44.24 0.000000000508 ***
# Residuals            150 2116.1    14.1
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = unlist(data[var_dep]) ~ unlist(data[factor]))
#
# $`unlist(data[factor])`
#                         diff       lwr       upr p adj
# Masculino-Femenino -4.081475 -5.293915 -2.869035     0
#
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Genero"
# [1] "Variable numérica: victima_psico"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0 . Es menor a 0.05; no se asume homogeneidad de varianzas. No es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0 . Es menor a 0.05; Se encuentran diferencias estadísticamente significativas entre los grupos"
#                       Df Sum Sq Mean Sq F value         Pr(>F)
# unlist(data[factor])   1   1504  1503.7   46.33 0.000000000224 ***
# Residuals            150   4869    32.5
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = unlist(data[var_dep]) ~ unlist(data[factor]))
#
# $`unlist(data[factor])`
#                         diff       lwr       upr p adj
# Masculino-Femenino -6.335206 -8.174308 -4.496105     0
#
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Orientación.sexual"
# [1] "Variable numérica: Edad"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.596 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.199 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   2   10.1   5.058   1.634  0.199
# Residuals            149  461.2   3.095
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Orientación.sexual"
# [1] "Variable numérica: apz_Reflexivo"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.755 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.755 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   2  0.064 0.03219   0.282  0.755
# Residuals            149 17.034 0.11432
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Orientación.sexual"
# [1] "Variable numérica: apz_sensitivo"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.636 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.406 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   2   1.06  0.5281   0.907  0.406
# Residuals            149  86.78  0.5824
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Orientación.sexual"
# [1] "Variable numérica: apz_intuitivo"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.25 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.25 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   2  0.507  0.2537     1.4   0.25
# Residuals            149 27.012  0.1813
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Orientación.sexual"
# [1] "Variable numérica: apz_visual"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.844 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.846 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   2   0.16  0.0804   0.168  0.846
# Residuals            149  71.31  0.4786
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Orientación.sexual"
# [1] "Variable numérica: apz_verbal"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.528 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.528 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   2   0.29  0.1429   0.642  0.528
# Residuals            149  33.18  0.2227
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Orientación.sexual"
# [1] "Variable numérica: apz_secuencial"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.664 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.242 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   2   1.28  0.6407   1.432  0.242
# Residuals            149  66.66  0.4474
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Orientación.sexual"
# [1] "Variable numérica: apz_global"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.269 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.281 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   2  0.521  0.2605    1.28  0.281
# Residuals            149 30.321  0.2035
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Orientación.sexual"
# [1] "Variable numérica: atacante_fis"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.598 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.784 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   2    6.9    3.44   0.244  0.784
# Residuals            149 2098.9   14.09
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Orientación.sexual"
# [1] "Variable numérica: atacante_psico"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.665 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.303 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   2    139   69.46   1.204  0.303
# Residuals            149   8599   57.71
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Orientación.sexual"
# [1] "Variable numérica: victima_fis"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.702 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.204 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   2   57.8    28.9   1.605  0.204
# Residuals            149 2682.4    18.0
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Orientación.sexual"
# [1] "Variable numérica: victima_psico"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.446 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.285 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   2    106   53.20   1.265  0.285
# Residuals            149   6266   42.05
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Tener.pareja"
# [1] "Variable numérica: Edad"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.11 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.086 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   1    9.2   9.214   2.991 0.0858 .
# Residuals            150  462.1   3.081
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Tener.pareja"
# [1] "Variable numérica: apz_Reflexivo"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.003 . Es menor a 0.05; no se asume homogeneidad de varianzas. No es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.003 . Es menor a 0.05; Se encuentran diferencias estadísticamente significativas entre los grupos"
#                       Df Sum Sq Mean Sq F value  Pr(>F)
# unlist(data[factor])   1  1.002  1.0016   9.333 0.00266 **
# Residuals            150 16.097  0.1073
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = unlist(data[var_dep]) ~ unlist(data[factor]))
#
# $`unlist(data[factor])`
#             diff        lwr         upr     p adj
# No-Si -0.1624762 -0.2675613 -0.05739104 0.0026641
#
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Tener.pareja"
# [1] "Variable numérica: apz_sensitivo"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.589 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.974 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   1   0.00  0.0006   0.001  0.974
# Residuals            150  87.83  0.5856
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Tener.pareja"
# [1] "Variable numérica: apz_intuitivo"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.718 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.718 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   1  0.024 0.02399   0.131  0.718
# Residuals            150 27.496 0.18331
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Tener.pareja"
# [1] "Variable numérica: apz_visual"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.847 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.847 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   1   0.02  0.0178   0.037  0.847
# Residuals            150  71.45  0.4763
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Tener.pareja"
# [1] "Variable numérica: apz_verbal"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.75 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.75 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   1   0.02 0.02268   0.102   0.75
# Residuals            150  33.44 0.22296
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Tener.pareja"
# [1] "Variable numérica: apz_secuencial"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.461 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.461 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   1   0.25  0.2467   0.547  0.461
# Residuals            150  67.69  0.4513
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Tener.pareja"
# [1] "Variable numérica: apz_global"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.843 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.843 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   1  0.008 0.00805   0.039  0.843
# Residuals            150 30.834 0.20556
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Tener.pareja"
# [1] "Variable numérica: atacante_fis"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.075 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.267 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   1   17.3   17.30   1.242  0.267
# Residuals            150 2088.5   13.92
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Tener.pareja"
# [1] "Variable numérica: atacante_psico"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.823 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.193 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   1     99   98.65   1.713  0.193
# Residuals            150   8639   57.59
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Tener.pareja"
# [1] "Variable numérica: victima_fis"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.877 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.159 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   1   36.1   36.13   2.004  0.159
# Residuals            150 2704.1   18.03
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Tener.pareja"
# [1] "Variable numérica: victima_psico"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.963 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.301 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   1     45   45.49   1.079  0.301
# Residuals            150   6327   42.18
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Tiempo"
# [1] "Variable numérica: Edad"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.448 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0 . Es menor a 0.05; Se encuentran diferencias estadísticamente significativas entre los grupos"
#                       Df Sum Sq Mean Sq F value      Pr(>F)
# unlist(data[factor])   5  118.7  23.738   9.828 0.000000041 ***
# Residuals            146  352.7   2.415
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = unlist(data[var_dep]) ~ unlist(data[factor]))
#
# $`unlist(data[factor])`
#                                      diff          lwr       upr     p adj
# 5 a 7 meses-Menos de 5 meses    0.2452174 -1.051579287 1.5420141 0.9941107
# 8 a 12 meses-Menos de 5 meses   0.4052174 -0.891579287 1.7020141 0.9453446
# 1 a 2 años-Menos de 5 meses     1.1505832 -0.018698942 2.3198654 0.0565581
# 3 a 5 años-Menos de 5 meses     2.5652174  1.280425932 3.8500089 0.0000007
# Más de 5 años-Menos de 5 meses  1.8152174  0.216893931 3.4135409 0.0160890
# 8 a 12 meses-5 a 7 meses        0.1600000 -1.109492637 1.4294926 0.9991493
# 1 a 2 años-5 a 7 meses          0.9053659 -0.233559414 2.0442911 0.2024986
# 3 a 5 años-5 a 7 meses          2.3200000  1.062773280 3.5772267 0.0000054
# Más de 5 años-5 a 7 meses       1.5700000 -0.006251191 3.1462512 0.0515627
# 1 a 2 años-8 a 12 meses         0.7453659 -0.393559414 1.8842911 0.4124481
# 3 a 5 años-8 a 12 meses         2.1600000  0.902773280 3.4172267 0.0000281
# Más de 5 años-8 a 12 meses      1.4100000 -0.166251191 2.9862512 0.1079643
# 3 a 5 años-1 a 2 años           1.4146341  0.289397178 2.5398711 0.0051486
# Más de 5 años-1 a 2 años        0.6646341 -0.808494166 2.1377625 0.7830187
# Más de 5 años-3 a 5 años       -0.7500000 -2.316389251 0.8163893 0.7372948
#
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Tiempo"
# [1] "Variable numérica: apz_Reflexivo"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.341 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.341 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   5  0.644  0.1288   1.143  0.341
# Residuals            146 16.455  0.1127
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Tiempo"
# [1] "Variable numérica: apz_sensitivo"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.165 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.944 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   5   0.72  0.1433    0.24  0.944
# Residuals            146  87.12  0.5967
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Tiempo"
# [1] "Variable numérica: apz_intuitivo"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.93 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.93 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   5  0.251  0.0502   0.269   0.93
# Residuals            146 27.269  0.1868
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Tiempo"
# [1] "Variable numérica: apz_visual"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.945 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.509 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   5   2.05  0.4097   0.862  0.509
# Residuals            146  69.42  0.4755
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Tiempo"
# [1] "Variable numérica: apz_verbal"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.689 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.689 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   5   0.69  0.1380   0.615  0.689
# Residuals            146  32.78  0.2245
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Tiempo"
# [1] "Variable numérica: apz_secuencial"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.725 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.306 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   5   2.71  0.5420   1.213  0.306
# Residuals            146  65.23  0.4468
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Tiempo"
# [1] "Variable numérica: apz_global"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.341 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.341 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   5   1.16  0.2321   1.141  0.341
# Residuals            146  29.68  0.2033
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Tiempo"
# [1] "Variable numérica: atacante_fis"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.055 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.12 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   5    121   24.21   1.781   0.12
# Residuals            146   1985   13.59
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Tiempo"
# [1] "Variable numérica: atacante_psico"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.666 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.059 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   5    607  121.42    2.18 0.0594 .
# Residuals            146   8130   55.69
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Tiempo"
# [1] "Variable numérica: victima_fis"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.032 . Es menor a 0.05; no se asume homogeneidad de varianzas. No es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.268 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   5  116.6   23.31   1.297  0.268
# Residuals            146 2623.7   17.97
# [1] "************************************************************"
# [1] "************************************************************"
# [1] "ANÁLISIS"
# [1] "Variable categórica: Tiempo"
# [1] "Variable numérica: victima_psico"
# [1] "************************************************************"
# [1] "prueba de levene, valor-p = 0.062 . Es mayor a 0.05; se asume homogeneidad de varianzas. Es viable comparar las medias de los grupos"
# [1] "ANOVA de una vía, valor-p = 0.419 . Es mayor a 0.05; No se encuentran diferencias estadísticamente significativas"
#                       Df Sum Sq Mean Sq F value Pr(>F)
# unlist(data[factor])   5    211   42.26   1.002  0.419
# Residuals            146   6161   42.20

# %%
for (factor in factores){
    for (var_dep in vars_deps){
        aov_test <- aov(unlist(data[var_dep]) ~ unlist(data[factor]))
        p_val_aov=summary(aov_test)[[1]][[1,"Pr(>F)"]]
        if (p_val_aov<.05){
            boxplot(unlist(data[var_dep]) ~ unlist(data[factor]),
                    main=paste("Diferencias en",var_dep, "por", factor ),
                    sub=paste("valor p=",round(p_val_aov,3)), 
                    xlab=factor,
                    ylab=var_dep,col="gray75")
        }
    }
}
# Out:
# Plot with title "Diferencias en apz_intuitivo por Entidad"
# Plot with title "Diferencias en apz_secuencial por Entidad"
# Plot with title "Diferencias en apz_intuitivo por Estrato"
# Plot with title "Diferencias en apz_visual por Estrato"
# Plot with title "Diferencias en apz_secuencial por Estrato"
# Plot with title "Diferencias en atacante_fis por Estrato"
# Plot with title "Diferencias en victima_fis por Estrato"
# Plot with title "Diferencias en victima_psico por Estrato"
# Plot with title "Diferencias en Edad por Genero"
# Plot with title "Diferencias en apz_Reflexivo por Genero"
# Plot with title "Diferencias en apz_intuitivo por Genero"
# Plot with title "Diferencias en victima_fis por Genero"
# Plot with title "Diferencias en victima_psico por Genero"
# Plot with title "Diferencias en apz_Reflexivo por Tener.pareja"
# Plot with title "Diferencias en Edad por Tiempo"
